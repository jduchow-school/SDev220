# %%
#7.4-7
things =["mozzarella" , "cinderella", "salmonella"]
things[1].capitalize()
# Out:
# 'Cinderella'

# %%
print(things)
# Out:
# ['mozzarella', 'cinderella', 'salmonella']

# %%
things[0].upper()
# Out:
# 'MOZZARELLA'

# %%
print(things)
# Out:
# ['mozzarella', 'cinderella', 'salmonella']

# %%
del things[-1]

# %%
print(things)
# Out:
# ['mozzarella', 'cinderella']

# %%
#if we wanted to make them permanent changes
things =["mozzarella" , "cinderella", "salmonella"]
things[1]=things[1].capitalize()
things[0]=things[0].upper()
del things[-1]
print(things)
# Out:
# ['MOZZARELLA', 'Cinderella']

# %%
#9.1-2
def good():
    return ['Harry','Ron','Hermione']
print(good())
# Out:
# ['Harry', 'Ron', 'Hermione']

# %%
def get_odds(first=1, last=10, step=2):
    number = first
    while number < last:
        yield number
        number+= step
test = get_odds()
count = 0
for x in test:
    count+=1
    if count==3:
        print(x)
        break
# Out:
# 5
